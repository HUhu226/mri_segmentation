# %% [markdown]
# # 数据处理

# %% [markdown]
# 按照2：8随机分train&test

# %%
import os
import random

# 设置文件夹路径
folder_path = '/code/CZQ/202311/data/all_200'
train_folder_path = '/code/CZQ/202311/data/train/raw'  # 训练集目录路径
test_folder_path = '/code/CZQ/202311/data/test/raw'    # 测试集目录路径

# 获取所有文件夹列表
all_folders = os.listdir(folder_path)

# 随机洗牌文件夹列表
random.shuffle(all_folders)

# 选择前121个文件夹作为训练集
train_folders = all_folders[:121]

# 选择后30个文件夹作为测试集
test_folders = all_folders[121:151]

# 创建训练集和测试集文件夹
os.makedirs(train_folder_path, exist_ok=True)
os.makedirs(test_folder_path, exist_ok=True)

# 移动文件夹到训练集和测试集
for folder in train_folders:
    src_folder = os.path.join(folder_path, folder)
    dest_folder = os.path.join(train_folder_path, folder)
    os.rename(src_folder, dest_folder)

for folder in test_folders:
    src_folder = os.path.join(folder_path, folder)
    dest_folder = os.path.join(test_folder_path, folder)
    os.rename(src_folder, dest_folder)

print("训练集和测试集创建完成。")
# Out:
# 训练集和测试集创建完成。

# %% [markdown]
# ## Section A. 查看未处理的seg_200数据

# %%
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt

nii_image = nib.load('/tmp/code/brain_seg/data/QJSH025/T1.nii.gz')
nii_data = nii_image.get_fdata()

numpy_array = np.array(nii_data)
numpy_array.shape
# Out:
# (208, 288, 288)

# %% [markdown]
# ↑原始数据维度
#
# ↓可视化，选择中间较有代表性的一个切片查看

# %%
# 选择一个切片的索引
slice_index = 50

# 获取选定切片的数据
slice_data = numpy_array[slice_index, :, :]  # 假设你要选择第 个切片

# 使用Matplotlib创建2D图像，以灰度显示
plt.imshow(slice_data, cmap='gray')  # 使用灰度颜色映射
plt.colorbar()

# 添加标题和标签
plt.title('2D Visualization (Slice {})'.format(slice_index))
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# 显示图像
plt.show()

# %% [markdown]
# ↑预期应该是一个后脑勺向上，颈部在左侧的图像

# %% [markdown]
# # Section B. 处理Train数据

# %% [markdown]
# 选取121例train

# %% [markdown]
# train切片为2D图像

# %%
import os
import nibabel as nib
import numpy as np

# 设置文件夹路径
folder_path_train_raw = '/code/CZQ/202311/data/train/raw'
valid_prefixes = ['CSVD', 'GZHU', 'QJ', 'SZKP']
#folder_num = 10

# 获取文件夹中所有子文件夹的名称
subfolders = os.listdir(folder_path_train_raw)

# %%
# 遍历每个子文件夹
ii = 0
for idx, subfolder in enumerate(subfolders):
    # 构建两个文件的完整路径
    if any (subfolder.startswith(prefix) for prefix in valid_prefixes):
        ii += 1
        print(f"--No.{ii} :{subfolder} --")
        
        nii_file1 = os.path.join(folder_path_train_raw, subfolder, 'T1.nii.gz')
        nii_file2 = os.path.join(folder_path_train_raw, subfolder, 'final_tissues.nii.gz')

        # 使用 nibabel 加载文件并提取数据
        img1 = nib.load(nii_file1).get_fdata()
        img2 = nib.load(nii_file2).get_fdata()
        #print(img1.shape)
        # 使用 squeeze 函数消除维度大小为1的维度
        img2 = np.squeeze(img2, axis=(3))
        #现在 imgx 将具有形状 (172, 512, 512)
         ##max - min normalization
        min_value = np.min(img1)
        max_value = np.max(img1)
        img1 = (img1 - min_value) / (max_value - min_value)
        #切片
        # 首先切片成 (512, 512) 的数据
        array_len = len(img1)
        for i in range(array_len):
# --No.100 :QJSH050 --
# --No.101 :QJCQ003 --
# --No.102 :QJSH021 --
# --No.103 :GZHU002 --
# --No.104 :SZKP034 --
# --No.105 :QJSH004 --
# --No.106 :SZKP031 --
# --No.107 :QJHK008 --
# --No.108 :QJSH005 --
# --No.109 :QJSH026 --
# --No.110 :CSVD001 --
# --No.111 :QJGZ015 --
# --No.112 :QJSH007 --
# --No.113 :QJSH043 --
# --No.114 :SZKP017 --
# --No.115 :CSVD009 --
# --No.116 :QJSH054 --
# --No.117 :QJSH045 --
# --No.118 :SZKP033 --
# --No.119 :SZKP003 --
# --No.120 :SZKP030 --
# --No.121 :SZKP024 --
# success

# %% [markdown]
# ## 检查处理后的数据

# %%
import numpy as np
import matplotlib.pyplot as plt

# 读取.npy文件
data = np.load('/code/CZQ/202311/data/train/00/QJGZ015_111.npy')
#data1 = np.load('/code/CZQ/202300/000/train/QJGZ015_111.npy')
print(data.shape)
#np.unique(data[1])
#print(data1)
# Out:
# (2, 256, 256)

# %%
# 获取切片0和切片1的数据
slice_data_0 = data[0, :, :]
slice_data_1 = data[1, :, :]

# 创建一个包含两个子图的图形
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# 在第一个子图中显示切片0的数据
ax1.imshow(slice_data_0, cmap='gray')
ax1.set_title('2D Visualization (T1)')
ax1.set_xlabel('X-axis')
ax1.set_ylabel('Y-axis')

# 在第二个子图中显示切片1的数据
ax2.imshow(slice_data_1, cmap='gray')
ax2.set_title('2D Visualization (Label)')
ax2.set_xlabel('X-axis')
ax2.set_ylabel('Y-axis')

# 显示图形
plt.tight_layout()
plt.show()

# %%
### QJSH033的不能要

import os

# 指定目录
directory = "/tmp/code/brain_seg/data00/train/00"

# 获取目录下所有文件
files = os.listdir(directory)

# 遍历文件，删除以"QJSH033"开头的文件
for file in files:
    if file.startswith("QJSH033"):
        file_path = os.path.join(directory, file)
        os.remove(file_path)
        print(f"Deleted file: {file_path}")
# Out:
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_188.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_043.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_158.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_065.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_096.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_071.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_151.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_046.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_209.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_178.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_141.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_155.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_221.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_044.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_246.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_176.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_132.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_128.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_036.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_024.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_145.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_108.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_062.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_009.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_000.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_130.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_183.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_173.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_223.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_244.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_241.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_131.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_242.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_109.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_207.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_027.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_229.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_074.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_177.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_023.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_057.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_126.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_077.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_146.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_143.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_045.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_129.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_179.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_200.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_004.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_099.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_069.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_153.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_070.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_181.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_165.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_106.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_092.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_144.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_116.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_111.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_235.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_182.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_032.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_168.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_053.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_050.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_159.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_224.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_162.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_049.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_218.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_185.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_028.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_011.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_190.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_100.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_219.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_123.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_090.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_010.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_114.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_022.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_216.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_251.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_249.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_234.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_019.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_035.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_202.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_076.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_169.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_003.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_068.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_214.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_110.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_048.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_101.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_215.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_017.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_012.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_255.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_088.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_038.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_217.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_213.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_120.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_127.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_237.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_079.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_172.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_013.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_060.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_112.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_007.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_231.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_113.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_115.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_252.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_240.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_085.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_184.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_002.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_075.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_142.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_047.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_067.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_186.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_014.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_232.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_220.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_081.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_058.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_199.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_197.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_030.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_117.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_040.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_064.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_080.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_026.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_059.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_119.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_066.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_204.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_094.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_233.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_189.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_157.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_148.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_054.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_034.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_160.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_228.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_167.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_083.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_061.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_093.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_164.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_008.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_180.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_192.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_195.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_015.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_102.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_248.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_016.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_039.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_031.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_006.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_042.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_170.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_139.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_021.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_037.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_238.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_018.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_107.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_087.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_206.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_198.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_125.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_118.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_254.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_225.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_211.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_055.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_063.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_134.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_056.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_163.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_245.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_154.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_033.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_243.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_078.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_089.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_150.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_193.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_082.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_166.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_212.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_247.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_156.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_098.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_025.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_095.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_029.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_253.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_191.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_147.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_239.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_230.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_201.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_222.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_203.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_084.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_072.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_187.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_051.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_105.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_210.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_136.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_205.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_137.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_227.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_086.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_073.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_226.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_135.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_171.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_020.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_005.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_175.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_124.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_174.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_122.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_149.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_196.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_121.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_140.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_194.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_250.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_052.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_161.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_103.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_236.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_097.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_041.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_208.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_138.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_104.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_152.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_133.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_091.npy
# Deleted file: /tmp/code/brain_seg/data00/train/00/QJSH033_001.npy

# %% [markdown]
# # Section C. 处理Test数据

# %% [markdown]
# test仍保持为3D图像

# %%
import os
import nibabel as nib
import numpy as np
# 设置文件夹路径
folder_path_test_raw = '/code/CZQ/202311/data/test/raw'
#folder_num = 10
valid_prefixes = ['CSVD', 'GZHU', 'QJ', 'SZKP']
# 获取文件夹中所有子文件夹的名称
subfolders = os.listdir(folder_path_test_raw)

# %%
# 遍历每个子文件夹
i = 0
for idx, subfolder in enumerate(subfolders):
    # 构建两个文件的完整路径
    if any (subfolder.startswith(prefix) for prefix in valid_prefixes):
        i += 1
        print(f"--No.{i} :{subfolder} --")
        nii_file1 = os.path.join(folder_path_test_raw, subfolder, 'T1.nii.gz')
        nii_file2 = os.path.join(folder_path_test_raw, subfolder, 'final_tissues.nii.gz')
        # 使用 nibabel 加载文件并提取数据
        img1 = nib.load(nii_file1).get_fdata()
        img2 = nib.load(nii_file2).get_fdata()
        #print(img1.shape)
        # 使用 squeeze 函数消除维度大小为1的维度
        img2 = np.squeeze(img2, axis=(3))
        #现在 imgx 将具有形状 (172, 512, 512)
        min_value = np.min(img1)
        max_value = np.max(img1)
        img1 = (img1 - min_value) / (max_value - min_value)
        #切片
        # 首先切片成 (512, 512) 的数据
        #array_len = len(img1)
        #for i in range(array_len):
        # 合并相同索引的切片，得到 (2, 512, 512) 的数据
        merged_slices = np.stack((img1, img2), axis=0)
        #np.shape(merged_slices)
        # 保存数据数组为 .npy 文件
        np.save(f'/code/CZQ/202311/data/test/00/{subfolder}.npy',merged_slices) 
print('success')
# Out:
# --No.1 :SZKP002 --
# --No.2 :QJSH024 --
# --No.3 :QJSH031 --
# --No.4 :QJSH032 --
# --No.5 :SZKP005 --
# --No.6 :CSVD004 --
# --No.7 :QJSH027 --
# --No.8 :QJSH014 --
# --No.9 :QJSH013 --
# --No.10 :QJGZ006 --
# --No.11 :QJGZ022 --
# --No.12 :QJSH008 --
# --No.13 :QJGZ005 --
# --No.14 :QJGZ019 --
# --No.15 :SZKP019 --
# --No.16 :QJSH002 --
# --No.17 :QJGZ009 --
# --No.18 :GZHU006 --
# --No.19 :SZKP011 --
# --No.20 :QJGZ029 --
# --No.21 :QJSH025 --
# --No.22 :SZKP007 --
# --No.23 :SZKP025 --
# --No.24 :QJGZ030 --
# --No.25 :QJGZ026 --
# --No.26 :GZHU003 --
# --No.27 :QJHK009 --
# --No.28 :SZKP026 --
# --No.29 :QJSH012 --
# --No.30 :SZKP015 --
# success

# %% [markdown]
# ## 检查处理后的数据
